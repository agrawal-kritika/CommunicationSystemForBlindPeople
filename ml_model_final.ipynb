# %%
import os
os.listdir("/Users/saisoorya/PycharmProjects/braille/braille data/data")

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rotation_range=20,
                             shear_range=10,
                             validation_split=0.2)

train_generator = datagen.flow_from_directory('/Users/saisoorya/PycharmProjects/braille/braille data/data',
                                              target_size=(28,28),
                                              subset='training')
# Out:
# Found 1360 images belonging to 27 classes.

# %%
from keras import backend as K
from keras import layers as L
from keras.models import Model,load_model
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint,ReduceLROnPlateau,EarlyStopping

K.clear_session()

model_ckpt = ModelCheckpoint('BrailleNet.h5',save_best_only=True)
reduce_lr = ReduceLROnPlateau(patience=8,verbose=0)
early_stop = EarlyStopping(patience=15,verbose=1)

entry = L.Input(shape=(28,28,3))
x = L.SeparableConv2D(64,(3,3),activation='relu')(entry)
x = L.MaxPooling2D((2,2))(x)
x = L.SeparableConv2D(128,(3,3),activation='relu')(x)
x = L.MaxPooling2D((2,2))(x)
x = L.SeparableConv2D(256,(2,2),activation='relu')(x)
x = L.GlobalMaxPooling2D()(x)
x = L.Dense(256)(x)
x = L.LeakyReLU()(x)
x = L.Dense(64,kernel_regularizer=l2(2e-4))(x)
x = L.LeakyReLU()(x)
x = L.Dense(29,activation='softmax')(x)

model = Model(entry,x)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['acc'])

history = model.fit_generator(train_generator,epochs=666,verbose=0)
# Out:
# Epoch 1/666
# /var/folders/qb/17cfgm351wz2s07gx63rcx0w0000gn/T/ipykernel_1833/119525516.py:29: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,epochs=666,verbose=1)
# 43/43 [==============================] - 1s 24ms/step - loss: 3.3048 - acc: 0.0412
# Epoch 2/666
# 43/43 [==============================] - 1s 23ms/step - loss: 3.1006 - acc: 0.1051
# Epoch 3/666
# 43/43 [==============================] - 1s 23ms/step - loss: 2.5361 - acc: 0.2669
# Epoch 4/666
# 43/43 [==============================] - 1s 23ms/step - loss: 1.8652 - acc: 0.4699
# Epoch 5/666
# 43/43 [==============================] - 1s 23ms/step - loss: 1.5140 - acc: 0.5640
# Epoch 6/666
# 43/43 [==============================] - 1s 23ms/step - loss: 1.2272 - acc: 0.6588
# Epoch 7/666
# 43/43 [==============================] - 1s 25ms/step - loss: 1.0101 - acc: 0.7368
# ...

# %%
import numpy as np

# %%
import tensorflow as tf

# %%
tf.keras.models.save_model(model,"model121.h5")
